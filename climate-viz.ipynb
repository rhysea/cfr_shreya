# %% [markdown]
# # Visualizations

# %% [markdown]
# In this tutorial, we introduce the basic visualization of climate datasets with `cfr`.

# %%
# %load_ext autoreload
# %autoreload 2

import cfr
import pandas as pd
import numpy as np
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load test data as `ClimateField`s

# %%
dirpath = 'data/GCM_sims/icesm_last_millennium_historical'

fd_tas = cfr.ClimateField().load_nc(os.path.join(dirpath, 'tas_sfc_Amon_iCESM_past1000historical_085001-200512.nc'))
fd_pr = cfr.ClimateField().load_nc(os.path.join(dirpath, 'pr_sfc_Amon_iCESM_past1000historical_085001-200512.nc'))

fd_tas.vn='tas'
fd_pr.vn='pr'

# %% [markdown]
# ## Plot a field map with a given time index

# %%
fig, ax = fd_tas.plot(it=-1)

# %%
# slice the data by index
fig, ax = fd_tas[-1].plot()
